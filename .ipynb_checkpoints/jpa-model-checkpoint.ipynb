# %% [markdown]
# # [Model Web Instrument](http://localhost/jcal/jpa-model.html)
# # [HOME](http://localhost/jcal/index.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import skrf as rf
from skrf.media import *
from skrf import Frequency
import json

# %% [markdown]
# [http://localhost/jcal/jpa-model.html](http://localhost/jcal/jpa-model.html)

# %%
fghz  = np.linspace(4,9,1601)
f = fghz*1e9
sopen = fghz*0j + 1
open_network = rf.Network(frequency=f, s=sopen, z0=50)
omega = 2*np.pi*f
f_coax = Frequency(fghz[0], fghz[len(fghz)-1], len(fghz), 'GHz')

# %% [markdown]
# $$
# L = L_0 + \frac{L_J^{min}}{|\cos{(2\pi\phi)}|}
# $$

# %%
while True:
    file_object = open("control.json", "r")
    try:
        control = json.loads(file_object.read())
    except ValueError:
        pass
    file_object.close()
    C_shunt = control['C0']
    L_shunt = control['L0'] + control['LJmin']/np.abs(np.cos(2*np.pi*control['phi']))
    Y_c_shunt = 1j*omega*control['C0']
    Y_l_shunt = 1/(1j*omega*L_shunt)
    c_in = control['Cin']
    Z_c_in = 1/(1j*2*np.pi*f*c_in)
    c_shunt_network = rf.Circuit.ShuntAdmittance(f, Y_c_shunt, name='shunt_admittance')
    l_shunt_network = rf.Circuit.ShuntAdmittance(f, Y_l_shunt, name='shunt_admittance2')
    cin_series_network = rf.Circuit.SeriesImpedance(f,Z_c_in,name='cin')
    jpa = cin_series_network**l_shunt_network**c_shunt_network**open_network
    coax = coaxial.Coaxial(f_coax,Dint=0.0005,Dout=0.001675,epsilon_r=2.1,sigma=1.2e7,z0_port=50)
    coax_length = coax.line(control['coax_length'], unit = 'm')
    coax_jpa = coax_length**cin_series_network**l_shunt_network**c_shunt_network**open_network
    phase =  coax_jpa.s_deg[:,0,0]
    model = {}
    model['fghz'] = fghz.tolist()
    model['phase'] = coax_jpa.s_deg[:,0,0].tolist()
    file_object = open("model.json", "w")
    json_string = file_object.write(json.dumps(model))
    file_object.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-64dc8207c602> in <module>
#      17     jpa = cin_series_network**l_shunt_network**c_shunt_network**open_network
#      18     coax = coaxial.Coaxial(f_coax,Dint=0.0005,Dout=0.001675,epsilon_r=2.1,sigma=1.2e7,z0_port=50)
# ---> 19     coax_length = coax.line(control['coax_length'], unit = 'm')
#      20     coax_jpa = coax_length**cin_series_network**l_shunt_network**c_shunt_network**open_network
#      21     phase =  coax_jpa.s_deg[:,0,0]
#
# ~\anaconda3\lib\site-packages\skrf\media\media.py in line(self, d, unit, z0, embed, **kwargs)
#    1029         # renormalize (or embed) into z0_port if required
#    1030         if self.z0_port is not None:
# -> 1031             result.renormalize(self.z0_port)
#    1032         result.renormalize(result.z0, s_def=s_def)
#    1033
#
# ~\anaconda3\lib\site-packages\skrf\network.py in renormalize(self, z_new, s_def)
#    3394                 self.s = s2s(self.s, self.z0, s_def, self.s_def)
#    3395             else:
# -> 3396                 self.s = renormalize_s(self.s, self.z0, z_new, s_def, self.s_def)
#    3397         # Update s_def if it was changed
#    3398         self.s_def = s_def
#
# ~\anaconda3\lib\site-packages\skrf\network.py in renormalize_s(s, z_old, z_new, s_def, s_def_old)
#    8115         raise ValueError('s_def parameter should be one of:', S_DEFINITIONS)
#    8116     # thats a heck of a one-liner!
# -> 8117     return z2s(s2z(s, z0=z_old, s_def=s_def_old), z0=z_new, s_def=s_def)
#    8118
#    8119 def fix_param_shape(p: NumberLike):
#
# ~\anaconda3\lib\site-packages\skrf\network.py in s2z(s, z0, s_def)
#    6738         sqrtz0 = np.zeros_like(s)
#    6739         np.einsum('ijj->ij', sqrtz0)[...] = np.sqrt(z0)
# -> 6740         z = sqrtz0 @ np.linalg.solve(mf.nudge_eig(Id - s), (Id + s) @ sqrtz0)
#    6741     else:
#    6742         raise ValueError(f'Unknown s_def: {s_def}')
#
# ~\anaconda3\lib\site-packages\numpy\core\overrides.py in solve(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in solve(a, b)
#     391     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     392     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 393     r = gufunc(a, b, signature=signature, extobj=extobj)
#     394
#     395     return wrap(r.astype(result_t, copy=False))
#
# KeyboardInterrupt:

# %%
phi = np.linspace(-0.5,0.5,1000)
L = control['LJmin']/np.abs(np.cos(2*np.pi*phi))
plt.plot(phi,L/1e-12)
plt.ylim(0,100)
plt.xlim(-0.25,0.25)
plt.grid()

# %%
file_object = open("control.json", "r")
try:
    control = json.loads(file_object.read())
except ValueError:
    pass
file_object.close()

C_shunt = control['C0']
L_shunt = control['LJmin']/np.abs(np.cos(2*np.pi*control['phi']))
Y_c_shunt = 1j*omega*control['C0']
Y_l_shunt = 1/(-50 + 1j*omega*L_shunt)
c_in = control['Cin']
Z_c_in = 1/(1j*2*np.pi*f*c_in)
c_shunt_network = rf.Circuit.ShuntAdmittance(f, Y_c_shunt, name='shunt_admittance')
l_shunt_network = rf.Circuit.ShuntAdmittance(f, Y_l_shunt, name='shunt_admittance2')
cin_series_network = rf.Circuit.SeriesImpedance(f,Z_c_in,name='cin')
jpa = cin_series_network**l_shunt_network**c_shunt_network**open_network
coax = coaxial.Coaxial(f_coax,Dint=0.0005,Dout=0.001675,epsilon_r=2.1,sigma=1.2e7,z0_port=50)
coax_length = coax.line(control['coax_length'], unit = 'm')
coax_jpa = coax_length**cin_series_network**l_shunt_network**c_shunt_network**open_network
plt.plot(fghz,coax_jpa.s_deg[:,0,0])
plt.grid()
model = {}
model['fghz'] = fghz.tolist()
model['phase'] = coax_jpa.s_deg[:,0,0].tolist()
file_object = open("model.json", "w")
json_string = file_object.write(json.dumps(model))
file_object.close()

# %%
C_shunt = control['C0']
L_shunt = control['L0'] + control['LJmin']/np.abs(np.cos(2*np.pi*control['phi']))
Y_c_shunt = 1j*omega*control['C0']
Y_l_shunt = 1/(1j*omega*L_shunt)

negativeR = -100
Y_gain_shunt = 1/negativeR
gain_shunt_network = rf.Circuit.ShuntAdmittance(f, Y_gain_shunt, name='gain_admittance')
c_in = control['Cin']
Z_c_in = 1/(1j*2*np.pi*f*c_in)
c_shunt_network = rf.Circuit.ShuntAdmittance(f, Y_c_shunt, name='shunt_admittance')
l_shunt_network = rf.Circuit.ShuntAdmittance(f, Y_l_shunt, name='shunt_admittance2')
cin_series_network = rf.Circuit.SeriesImpedance(f,Z_c_in,name='cin')
jpa = cin_series_network**l_shunt_network**c_shunt_network**open_network
coax = coaxial.Coaxial(f_coax,Dint=0.0005,Dout=0.001675,epsilon_r=2.1,sigma=1.2e7,z0_port=50)
coax_length = coax.line(control['coax_length'], unit = 'm')
coax_jpa = coax_length**cin_series_network**gain_shunt_network**l_shunt_network**c_shunt_network**open_network
phase =  coax_jpa.s_deg[:,0,0]
model = {}
model['fghz'] = fghz.tolist()
model['phase'] = coax_jpa.s_deg[:,0,0].tolist()
file_object = open("model.json", "w")
json_string = file_object.write(json.dumps(model))
file_object.close()
plt.plot(fghz,coax_jpa.s_db[:,0,0])
plt.grid()
