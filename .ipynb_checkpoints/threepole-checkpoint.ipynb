# %%
import numpy as np
import matplotlib.pyplot as plt
import skrf as rf
from skrf.media import *
from skrf import Frequency
import json

# %%
file_object = open("threepole-components.json", "r")
try:
    components = json.loads(file_object.read())
except ValueError:
    pass

fghz  = np.linspace(4,9,1000)
f = fghz*1e9
sopen = fghz*0j + 1
open_network = rf.Network(frequency=f, s=sopen, z0=50)
omega = 2*np.pi*f
YC1 = 1j*omega*components['C1']
YC2 = 1j*omega*components['C2']
YC3 = 1j*omega*components['C3']
ZL1 = 1j*omega*components['L1']
ZL2 = 1j*omega*components['L2']
ZL3 = 1j*omega*components['L3']

C1_network = rf.Circuit.ShuntAdmittance(f,YC1, name='YC1')
L1_network = rf.Circuit.SeriesImpedance(f,ZL1, name='ZL1')
C2_network = rf.Circuit.ShuntAdmittance(f,YC2, name='YC2')
L2_network = rf.Circuit.SeriesImpedance(f,ZL2, name='ZL2')
C3_network = rf.Circuit.ShuntAdmittance(f,YC3, name='YC3')
L3_network = rf.Circuit.SeriesImpedance(f,ZL3, name='ZL3')

threepole_network = L3_network**C3_network**L2_network**C2_network**L1_network**C1_network**open_network

trace = {}
trace['fghz'] = fghz.tolist()
trace['phase'] = threepole_network.s_deg[:,0,0].tolist()
file_object = open("threepole-trace.json", "w")
json_string = file_object.write(json.dumps(trace))
file_object.close()
plt.plot(fghz,threepole_network.s_deg[:,0,0])
plt.grid()

# %%
while True:
    file_object = open("threepole-components.json", "r")
    try:
        components = json.loads(file_object.read())
    except ValueError:
        pass

    fghz  = np.linspace(4,9,1000)
    f = fghz*1e9
    sopen = fghz*0j + 1
    open_network = rf.Network(frequency=f, s=sopen, z0=50)
    omega = 2*np.pi*f
    YC1 = 1j*omega*components['C1']
    YC2 = 1j*omega*components['C2']
    YC3 = 1j*omega*components['C3']
    ZL1 = 1j*omega*components['L1']
    ZL2 = 1j*omega*components['L2']
    ZL3 = 1j*omega*components['L3']

    C1_network = rf.Circuit.ShuntAdmittance(f,YC1, name='YC1')
    L1_network = rf.Circuit.SeriesImpedance(f,ZL1, name='ZL1')
    C2_network = rf.Circuit.ShuntAdmittance(f,YC2, name='YC2')
    L2_network = rf.Circuit.SeriesImpedance(f,ZL2, name='ZL2')
    C3_network = rf.Circuit.ShuntAdmittance(f,YC3, name='YC3')
    L3_network = rf.Circuit.SeriesImpedance(f,ZL3, name='ZL3')

    threepole_network = L3_network**C3_network**L2_network**C2_network**L1_network**C1_network**open_network

    trace = {}
    trace['fghz'] = fghz.tolist()
    trace['phase'] = threepole_network.s_deg[:,0,0].tolist()
    file_object = open("threepole-trace.json", "w")
    json_string = file_object.write(json.dumps(trace))
    file_object.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-0a5298dd4ddb> in <module>
#       9     f = fghz*1e9
#      10     sopen = fghz*0j + 1
# ---> 11     open_network = rf.Network(frequency=f, s=sopen, z0=50)
#      12     omega = 2*np.pi*f
#      13     YC1 = 1j*omega*components['C1']
#
# ~\anaconda3\lib\site-packages\skrf\network.py in __init__(self, file, name, params, comments, f_unit, s_def, **kwargs)
#     494         for attr in list(PRIMARY_PROPERTIES) + ['frequency', 'noise', 'noise_freq']:
#     495             if attr in kwargs:
# --> 496                 self.__setattr__(attr, kwargs[attr])
#     497
#     498     @classmethod
#
# ~\anaconda3\lib\site-packages\skrf\network.py in frequency(self, new_frequency)
#    1427         else:
#    1428             try:
# -> 1429                 self._frequency = Frequency.from_f(new_frequency, unit=self.frequency.unit)
#    1430             except TypeError as err:
#    1431                 raise TypeError('Could not convert argument to a frequency vector') from err
#
# ~\anaconda3\lib\site-packages\skrf\frequency.py in from_f(cls, f, unit)
#     273         temp_freq =  cls(0,0,0,unit=unit)
#     274         temp_freq._f = np.asarray(f) * temp_freq.multiplier
# --> 275         temp_freq.check_monotonic_increasing()
#     276
#     277         return temp_freq
#
# ~\anaconda3\lib\site-packages\skrf\frequency.py in check_monotonic_increasing(self)
#     347         """
#     348         increase = np.diff(self.f) > 0
# --> 349         if not increase.all():
#     350             warnings.warn("Frequency values are not monotonously increasing!\n"
#     351             "To get rid of the invalid values call `drop_non_monotonic_increasing`",
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _all(a, axis, dtype, out, keepdims, where)
#      61     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      62     if where is True:
# ---> 63         return umr_all(a, axis, dtype, out, keepdims)
#      64     return umr_all(a, axis, dtype, out, keepdims, where=where)
#      65
#
# KeyboardInterrupt:

# %%
file_object = open("threepole-components.json", "r")
try:
    components = json.loads(file_object.read())
except ValueError:
    pass

fghz  = np.linspace(4,9,1000)
f = fghz*1e9
sopen = fghz*0j + 1
open_network = rf.Network(frequency=f, s=sopen, z0=50)
omega = 2*np.pi*f
YC1 = 1j*omega*components['C1']*3.1
YC2 = 1j*omega*components['C2']*2.8
YC3 = 1j*omega*components['C3']*1.3
ZL1 = 1j*omega*components['L1']*3.4
ZL2 = 1j*omega*components['L2']*2.2
ZL3 = 1j*omega*components['L3']*3.6

C1_network = rf.Circuit.ShuntAdmittance(f,YC1, name='YC1')
L1_network = rf.Circuit.SeriesImpedance(f,ZL1, name='ZL1')
C2_network = rf.Circuit.ShuntAdmittance(f,YC2, name='YC2')
L2_network = rf.Circuit.SeriesImpedance(f,ZL2, name='ZL2')
C3_network = rf.Circuit.ShuntAdmittance(f,YC3, name='YC3')
L3_network = rf.Circuit.SeriesImpedance(f,ZL3, name='ZL3')

threepole_network = L3_network**C3_network**L2_network**C2_network**L1_network**C1_network**open_network

plt.plot(fghz,threepole_network.s_deg_unwrap[:,0,0])
plt.grid()
